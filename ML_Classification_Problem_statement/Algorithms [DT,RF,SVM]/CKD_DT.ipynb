# %%
import pandas as pd

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)

# %%
dataset
# Out:
#      age  bp  al  su  bgr   bu  sc  sod  pot  hrmo  ...  pc_normal  \
# 0      2  76   3   0  148   57   3  137    4    12  ...          0
# 1      3  76   2   0  148   22   0  137    4    10  ...          1
# 2      4  76   1   0   99   23   0  138    4    12  ...          1
# 3      5  76   1   0  148   16   0  138    3     8  ...          1
# 4      5  50   0   0  148   25   0  137    4    11  ...          1
# ..   ...  ..  ..  ..  ...  ...  ..  ...  ...   ...  ...        ...
# 394   51  70   0   0  219   36   1  139    3    12  ...          1
# 395   51  70   0   2  220   68   2  137    4     8  ...          1
# 396   51  70   3   0  110  115   6  134    2     9  ...          1
# 397   51  90   0   0  207   80   6  142    5     8  ...          1
# 398   51  80   0   0  100   49   1  140    5    16  ...          1
#
#      pcc_present  ba_present  htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  \
# 0              0           0        0       0        0          1       1
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
dataset.value_counts('classification_yes')
# Out:
# classification_yes
# 1    249
# 0    150
# Name: count, dtype: int64

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]

# %%
dep=dataset[['classification_yes']]

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'criterion':["gini", "entropy", "log_loss"],'splitter':["best",'random']}
grid=GridSearchCV(DecisionTreeClassifier(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print(grid.best_params_)
# Out:
# {'criterion': 'log_loss', 'splitter': 'random'}

# %%
grid_prediction=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_prediction)
print(cm)
# Out:
# [[50  1]
#  [ 1 81]]

# %%
from sklearn.metrics import classification_report as clf_report
clf=clf_report(y_test,grid_prediction)
print(clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        51
#            1       0.99      0.99      0.99        82
#
#     accuracy                           0.98       133
#    macro avg       0.98      0.98      0.98       133
# weighted avg       0.98      0.98      0.98       133

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid_prediction)
# Out:
# np.float64(0.9840985174557627)

# %%
scy=StandardScaler()
y_train=scy.fit_transform(y_train)
y_test=scy.transform(y_test)

# %%
age=int(input("Enter the Age:"))
bp=int(input("Enter BP : "))
al=int(input("Enter the AL : "))
su=int(input("Enter the SU : "))
bgr=int(input("Enter the BGR : "))
bu=int(input("Enter the BU : "))
sc=int(input("Enter the SC : "))
sod=int(input("Enter the SOD : "))
pot=int(input("Enter the POT : "))
hrmo=int(input("Enter the Hrmo : "))
pcv=int(input("Enter the PCV : "))
wc=int(input("Enter the WC : "))
rc=int(input("Enter the RC : "))
sg_b=int(input("Enter the SG_B : "))
sg_c=int(input("Enter the SG_C : "))
sg_d=int(input("Enter the SG_D : "))
sg_e=int(input("Enter the SG_E : "))
rbc_normal=int(input("Enter the RBC_Normal : "))
pc_normal=int(input('Enter the PC_normal : '))
pcc_present=int(input('Enter the PCC_Present : '))
ba_present=int(input('Enter the BA_Present : '))
htn_yes=int(input('Enter the HTN 0 or 1: '))
dm_yes=int(input('Enter the DM 0 or 1: '))
cad_yes=int(input('Enter the cad 0 or 1 : '))
appet_yes=int(input('Enter the Appet 0 or 1 : '))
pe_yes=int(input('Enter the Pe 0 or 1: '))
ane_yes=int(input('Enter the Ane 0 or 1: '))
# Out:
# Enter the Age: 17
# Enter BP :  89
# Enter the AL :  34
# Enter the SU :  3
# Enter the BGR :  4
# Enter the BU :  2
# Enter the SC :  4
# Enter the SOD :  25
# Enter the POT :  3
# Enter the Hrmo :  5
# Enter the PCV :  32
# Enter the WC :  4
# Enter the RC :  3
# Enter the SG_B :  2
# Enter the SG_C :  4
# Enter the SG_D :  3
# Enter the SG_E :  2
# Enter the RBC_Normal :  4
# Enter the PC_normal :  1
# Enter the PCC_Present :  1
# Enter the BA_Present :  1
# Enter the HTN 0 or 1:  1
# Enter the DM 0 or 1:  1
# Enter the cad 0 or 1 :  1
# Enter the Appet 0 or 1 :  1
# Enter the Pe 0 or 1:  1
# Enter the Ane 0 or 1:  1

# %%
Future_Prediction=grid.predict([[age,bp,al,su,bgr,bu,sc,sod,pot,hrmo,pcv,
       wc,rc,sg_b,sg_c,sg_d,sg_e,rbc_normal,pc_normal,
       pcc_present,ba_present,htn_yes,dm_yes,cad_yes,
       appet_yes,pe_yes,ane_yes]])
preOutput=scy.inverse_transform([Future_Prediction])
print(preOutput)
# Out:
# [[1.11120569]]
