# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Wine.csv')
x=dataset.iloc[:,0:13].values
y=dataset.iloc[:,13].values

# %%
dataset=pd.get_dummies('prep.csv')

# %%
#splitting the dataset into the training and test set
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2,random_state=0)

# %%
#Feature Scaling 
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
# !pip install PCA
# Out:
# Collecting PCA
#   Downloading pca-2.10.2-py3-none-any.whl.metadata (12 kB)
# Collecting datazets (from PCA)
#   Downloading datazets-1.1.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: statsmodels in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from PCA) (0.14.6)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from PCA) (3.9.2)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from PCA) (2.1.2)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from PCA) (1.5.2)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from PCA) (1.16.3)
# Collecting colourmap>=1.1.19 (from PCA)
#   Downloading colourmap-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from PCA) (2.2.3)
# Collecting scatterd>=1.3.7 (from PCA)
#   Downloading scatterd-1.4.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting adjusttext (from PCA)
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: seaborn in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from scatterd>=1.3.7->PCA) (0.13.2)
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from datazets->PCA) (2.32.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from matplotlib->PCA) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from matplotlib->PCA) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from matplotlib->PCA) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from matplotlib->PCA) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from matplotlib->PCA) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from matplotlib->PCA) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from matplotlib->PCA) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from matplotlib->PCA) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from python-dateutil>=2.7->matplotlib->PCA) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from pandas->PCA) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from pandas->PCA) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from requests->datazets->PCA) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from requests->datazets->PCA) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from requests->datazets->PCA) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from requests->datazets->PCA) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from scikit-learn->PCA) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from scikit-learn->PCA) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\user\anaconda3\envs\aiml\lib\site-packages (from statsmodels->PCA) (1.0.2)
# Downloading pca-2.10.2-py3-none-any.whl (35 kB)
# Downloading colourmap-1.2.1-py3-none-any.whl (10 kB)
# Downloading scatterd-1.4.2-py3-none-any.whl (13 kB)
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Downloading datazets-1.1.3-py3-none-any.whl (190 kB)
# Installing collected packages: datazets, colourmap, adjusttext, scatterd, PCA
#
#    ---------------- ----------------------- 2/5 [adjusttext]
#    ---------------------------------------- 5/5 [PCA]
#
# Successfully installed PCA-2.10.2 adjusttext-1.3.0 colourmap-1.2.1 datazets-1.1.3 scatterd-1.4.2

# %%
#Applying PCA
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
x_train=pca.fit_transform(x_train)
x_test=pca.fit_transform(x_test)
explained_varaince=pca.explained_variance_ratio_

# %%
#fitting Logisitic Regression to the Training Set
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
#predicting the test set results
y_pred=classifier.predict(x_test)

# %%
#Making the confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)

# %%
#Visualising the training set results
from matplotlib.colors import ListedColormap
x_set,y_set=x_train,y_train
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min()-1,stop=x_set[:,0].max()+1,step=0.01),
                 np.arange(start=x_set[:,1].min()-1,stop=x_set[:,1].max()+1,step=0.01))
plt.contour(x1,x2,classifier.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape),
           alpha=0.75,cmap=ListedColormap(('red',"green",'blue')))
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j,0],x_set[y_set==j,1],
               c=ListedColormap(('red','green','blue'))(i),label=j)
plt.title('Logistic Regression (train set)')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11340\3519278215.py:11: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x_set[y_set==j,0],x_set[y_set==j,1],

# %%
#Visualising the training set results
from matplotlib.colors import ListedColormap
x_set,y_set=x_test,y_test
x1,x2=np.meshgrid(np.arange(start=x_set[:,0].min()-1,stop=x_set[:,0].max()+1,step=0.01),
                 np.arange(start=x_set[:,1].min()-1,stop=x_set[:,1].max()+1,step=0.01))
plt.contour(x1,x2,classifier.predict(np.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape),
           alpha=0.75,cmap=ListedColormap(('red',"green",'blue')))
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set==j,0],x_set[y_set==j,1],
               c=ListedColormap(('red','green','blue'))(i),label=j)
plt.title('Logistic Regression (test set)')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11340\3263515225.py:11: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x_set[y_set==j,0],x_set[y_set==j,1],
