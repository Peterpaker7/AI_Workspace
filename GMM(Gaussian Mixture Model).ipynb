# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
dataset=pd.read_csv("Mall_Customers.csv")
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
#dataset=pd.get_dummies(dataset)
#dataset

# %%
x=dataset.iloc[:,[3,4]].values

# %%
from sklearn.mixture import GaussianMixture as GM
GMM=GM(n_components=3, covariance_type='full')
y_gmm=GMM.fit(x)

# %%
supervised=pd.DataFrame(dataset)
supervised['Cluster_Group']=y_gmm
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#                        Cluster_Group
# 0    GaussianMixture(n_components=3)
# 1    GaussianMixture(n_components=3)
# 2    GaussianMixture(n_components=3)
# 3    GaussianMixture(n_components=3)
# 4    GaussianMixture(n_components=3)
# ..                               ...
# 195  GaussianMixture(n_components=3)
# 196  GaussianMixture(n_components=3)
# 197  GaussianMixture(n_components=3)
# 198  GaussianMixture(n_components=3)
# 199  GaussianMixture(n_components=3)
#
# [200 rows x 6 columns]

# %%
facet=sns.lmplot(data=supervised,x=supervised.columns[3],y=supervised.columns[4],hue=supervised.columns[5],fit_reg=False
                ,legend=True,legend_out=True)
# Out:
# C:\Users\USER\anaconda3\envs\aiml\Lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
