# %%
import pandas as pd
from Univariate import SplitOF

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
q,qun=SplitOF.QuanQual(dataset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 q,qun=SplitOF.QuanQual(dataset)
#
# TypeError: SplitOF.QuanQual() takes 0 positional arguments but 1 was given
